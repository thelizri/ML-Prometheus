# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from prometheus_api_client import PrometheusConnect
from math import sqrt
import datetime
# Out:
# 2024-03-21 18:22:33.259723: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
PROMETHEUS_URL = 'http://localhost:9090'
PROMETHEUS_ACCESS_TOKEN = ''  

# Initialize Prometheus connection
prom = PrometheusConnect(url=PROMETHEUS_URL, disable_ssl=True)

# Queries
ram_query = '100 - ((avg_over_time(node_memory_MemAvailable_bytes{instance="172.16.101.106:9100",job="kubernetes-service-endpoints"}[5m15s]) * 100) / avg_over_time(node_memory_MemTotal_bytes{instance="172.16.101.106:9100",job="kubernetes-service-endpoints"}[5m15s]))'
cpu_query = '(sum by(instance) (irate(node_cpu_seconds_total{instance="172.16.101.106:9100",job="kubernetes-service-endpoints", mode!="idle"}[5m15s])) / on(instance) group_left sum by (instance)((irate(node_cpu_seconds_total{instance="172.16.101.106:9100",job="kubernetes-service-endpoints"}[5m15s])))) * 100'

# %%
def make_query(query, start_days_ago, step):
    end_time = datetime.datetime.now()
    start_time = end_time - datetime.timedelta(days=start_days_ago)
    data = prom.custom_query_range(query=query, start_time=start_time, end_time=end_time, step=step)
    return data

# %%
data = make_query(cpu_query, 7, 60)

# %%
len(data[0]["values"])
# Out:
# 10081

# %%
timestamps = [
            datetime.datetime.fromtimestamp(float(item[0]))
            for item in data[0]["values"]
        ]

# %%
delta = timestamps[-1] - timestamps[-2]

# %%
d = datetime.timedelta(days=10)

# %%
d/delta
# Out:
# 14400.0

# %%
def gen_timestamps(timestamps, n=10):
    delta = timestamps[-1] - timestamps[-2] # Assumes uniformity
    new_timeseries = [timestamps[-1] + i*delta for i in range(n)]
    return new_timeseries

# %%
gen_timestamps(timestamps)
# Out:
# [datetime.datetime(2024, 3, 21, 18, 56, 25),
#  datetime.datetime(2024, 3, 21, 18, 57, 25),
#  datetime.datetime(2024, 3, 21, 18, 58, 25),
#  datetime.datetime(2024, 3, 21, 18, 59, 25),
#  datetime.datetime(2024, 3, 21, 19, 0, 25),
#  datetime.datetime(2024, 3, 21, 19, 1, 25),
#  datetime.datetime(2024, 3, 21, 19, 2, 25),
#  datetime.datetime(2024, 3, 21, 19, 3, 25),
#  datetime.datetime(2024, 3, 21, 19, 4, 25),
#  datetime.datetime(2024, 3, 21, 19, 5, 25)]

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=3):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i : (i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
def build_lstm(learning_rate, look_back):
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, look_back), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(25, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss="mean_squared_error", optimizer=Adam(learning_rate))
    return model

# %%
def print_rsme(trainY, testY, trainPredict, testPredict):
    trainScore = sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
    testScore = sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
    print("Train Score: %.2f RMSE" % (trainScore))
    print("Test Score: %.2f RMSE" % (testScore))

# %%
def visualize(df, trainPredict, testPredict, future_timestamps, future_predictions, name="value", look_back=3):
    # Visualization
    plt.figure(figsize=(15, 6))
    plt.plot(df["timestamp"], df[name], label="Original Data")
    plt.plot(
        df["timestamp"],
        np.pad(
            trainPredict.ravel(),
            (look_back, len(df) - len(trainPredict) - look_back),
            "constant",
            constant_values=np.nan,
        ),
        label="Train Prediction",
    )
    plt.plot(
        df["timestamp"],
        np.pad(
            testPredict.ravel(),
            (
                len(trainPredict) + 2 * look_back + 1,
                len(df) - len(testPredict) - len(trainPredict) - 2 * look_back - 1,
            ),
            "constant",
            constant_values=np.nan,
        ),
        label="Test Prediction",
    )
    
    # Plot future predictions
    if future_timestamps and future_predictions:
        plt.plot(future_timestamps, future_predictions, "r--", label="Future Predictions")
    
    plt.title(f"{name} Prediction")
    plt.xlabel("Timestamp")
    plt.ylabel(name)
    plt.legend()
    plt.show()

# %%
def predict(
    prom,
    query,
    name="value",
    start_days_ago=7,
    step="60",
    look_back=3,
    epochs=1000,
    batch_size=1,
    patience=10,
    learning_rate=0.0005,
):
    data = make_query(query, start_days_ago, step)[0]["values"]

    if data:
        timestamps = [
            datetime.datetime.fromtimestamp(float(item[0]))
            for item in data
        ]
        value = [float(item[1]) for item in data]

        df = pd.DataFrame(data={"timestamp": timestamps, name: value})
        df["timestamp"] = pd.to_datetime(df["timestamp"])

        # Normalize the dataset
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_data = scaler.fit_transform(df[name].values.reshape(-1, 1))


        train_size = int(len(scaled_data) * 0.67)
        test_size = len(scaled_data) - train_size
        train, test = (
            scaled_data[0:train_size, :],
            scaled_data[train_size : len(scaled_data), :],
        )

        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)

        trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
        testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

        # Build the LSTM model
        model = build_lstm(learning_rate, look_back)

        # Fit the model with early stopping
        early_stop = EarlyStopping(monitor="val_loss", patience=patience, verbose=1)
        history = model.fit(
            trainX,
            trainY,
            epochs=epochs,
            batch_size=batch_size,
            verbose=1,
            validation_data=(testX, testY),
            callbacks=[early_stop],
        )

        # Predictions for training and testing dataset
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # Invert predictions
        trainPredict = scaler.inverse_transform(trainPredict)
        trainY = scaler.inverse_transform([trainY])
        testPredict = scaler.inverse_transform(testPredict)
        testY = scaler.inverse_transform([testY])

        # Calculate RMSE
        print_rsme(trainY, testY, trainPredict, testPredict)
        
        # Function to predict the next 10 days
        def predict_next_10_days(input_data, model, scaler, look_back):
            delta = timestamps[-1] - timestamps[-2]
            i = int(datetime.timedelta(days=10)/delta)
            new_timestamps = gen_timestamps(timestamps, n=i)
            future_predictions = []
            current_input = input_data[-look_back:].reshape(1, 1, look_back)
            for _ in range(i):  # Predict 10 days into the future
                # Predict the next value
                predicted_value = model.predict(current_input)
                future_predictions.append(scaler.inverse_transform(predicted_value)[0][0])
                
                # Update the current input to include the new prediction
                current_input = np.append(current_input[0, 0, 1:], predicted_value).reshape(1, 1, look_back)
            
            return future_predictions, new_timestamps

        # Predict future values
        last_known_data = scaled_data[-look_back:]
        future_predictions, new_timestamps = predict_next_10_days(last_known_data, model, scaler, look_back)
        
        # Visualisation
        visualize(df, trainPredict, testPredict, new_timestamps, future_predictions, name, look_back)
    else:
        print("No data returned from Prometheus or unexpected data format.")

# %%
predict(prom, cpu_query, name="CPU Busy", patience=40, step="3600", epochs=100, start_days_ago=30)
# Out:
# Epoch 1/100
# /Users/william/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0521e-04 - val_loss: 0.1194
# Epoch 2/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1817e-04 - val_loss: 0.0861
# Epoch 3/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5329e-04 - val_loss: 0.0426
# Epoch 4/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1569e-04 - val_loss: 0.0169
# Epoch 5/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2597e-05 - val_loss: 0.0102
# Epoch 6/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3218e-04 - val_loss: 0.0099
# Epoch 7/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6822e-05 - val_loss: 0.0088
# Epoch 8/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7979e-04 - val_loss: 0.0090
# Epoch 9/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1298e-04 - val_loss: 0.0081
# Epoch 10/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6498e-04 - val_loss: 0.0079
# Epoch 11/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1746e-05 - val_loss: 0.0086
# Epoch 12/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3461e-04 - val_loss: 0.0084
# Epoch 13/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0496e-04 - val_loss: 0.0089
# Epoch 14/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2240e-04 - val_loss: 0.0112
# Epoch 15/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4928e-04 - val_loss: 0.0102
# Epoch 16/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3018e-04 - val_loss: 0.0100
# Epoch 17/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1614e-04 - val_loss: 0.0108
# Epoch 18/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2072e-04 - val_loss: 0.0084
# Epoch 19/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7779e-04 - val_loss: 0.0084
# Epoch 20/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5876e-05 - val_loss: 0.0079
# Epoch 21/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5714e-04 - val_loss: 0.0100
# Epoch 22/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1406e-04 - val_loss: 0.0085
# Epoch 23/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2695e-05 - val_loss: 0.0092
# Epoch 24/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0358e-04 - val_loss: 0.0103
# Epoch 25/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6569e-05 - val_loss: 0.0097
# Epoch 26/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0773e-05 - val_loss: 0.0114
# Epoch 27/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8212e-05 - val_loss: 0.0113
# Epoch 28/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1004e-04 - val_loss: 0.0125
# Epoch 29/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0414e-04 - val_loss: 0.0106
# Epoch 30/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0237e-04 - val_loss: 0.0103
# Epoch 31/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9846e-05 - val_loss: 0.0100
# Epoch 32/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5277e-05 - val_loss: 0.0103
# Epoch 33/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6956e-05 - val_loss: 0.0084
# Epoch 34/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3125e-05 - val_loss: 0.0086
# Epoch 35/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0169e-04 - val_loss: 0.0089
# Epoch 36/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1216e-04 - val_loss: 0.0099
# Epoch 37/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2000e-05 - val_loss: 0.0091
# Epoch 38/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0560e-04 - val_loss: 0.0122
# Epoch 39/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0265e-04 - val_loss: 0.0104
# Epoch 40/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1610e-04 - val_loss: 0.0125
# Epoch 41/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4513e-04 - val_loss: 0.0125
# Epoch 42/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4343e-04 - val_loss: 0.0091
# Epoch 43/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0640e-05 - val_loss: 0.0116
# Epoch 44/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2139e-04 - val_loss: 0.0096
# Epoch 45/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2689e-04 - val_loss: 0.0112
# Epoch 46/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9599e-05 - val_loss: 0.0123
# Epoch 47/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9546e-05 - val_loss: 0.0131
# Epoch 48/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8875e-05 - val_loss: 0.0140
# Epoch 49/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0292e-05 - val_loss: 0.0116
# Epoch 50/100
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6367e-05 - val_loss: 0.0108
# Epoch 50: early stopping
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train Score: 0.83 RMSE
# Test Score: 9.03 RMSE
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
predict(prom, ram_query, name="RAM Usage", patience=40, step="600", epochs=100, start_days_ago=7)
# Out:
# Epoch 1/100
# /Users/william/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1214 - val_loss: 0.0053
# Epoch 2/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0093 - val_loss: 0.0025
# Epoch 3/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0084 - val_loss: 0.0019
# Epoch 4/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0094 - val_loss: 0.0019
# Epoch 5/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0085 - val_loss: 0.0018
# Epoch 6/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0078 - val_loss: 0.0018
# Epoch 7/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0074 - val_loss: 0.0018
# Epoch 8/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 9/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 10/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 11/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 12/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 13/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 14/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 15/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 16/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 17/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 18/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 19/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 20/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 21/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 22/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 23/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 24/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 25/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 26/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 27/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 28/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 29/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 30/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 31/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 32/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 33/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 34/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 35/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 36/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 37/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 38/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 39/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 40/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 41/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 42/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 43/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 44/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 45/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 46/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 47/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 48/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 49/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 50/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 51/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 52/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 53/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 54/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 55/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 56/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 57/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 58/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 59/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 60/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 61/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 62/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 63/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 64/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 65/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 66/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 67/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 68/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 69/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 70/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 71/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 72/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 73/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 74/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 75/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 76/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 77/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 78/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 79/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 80/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 81/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 82/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 83/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 84/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 85/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 86/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 87/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 88/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 89/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 90/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 91/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 92/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 93/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 94/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 95/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 96/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 97/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 98/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 99/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 100/100
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0039 - val_loss: 0.0021
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Train Score: 0.55 RMSE
# Test Score: 0.63 RMSE
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
